# %% [markdown]
# Jupyter notebook to understand Satellite images

# %%
import rasterio
import glob
import os

# %% [markdown]
# Open image 'stack.tif' from example folder

# %%
dataset = rasterio.open('stack.tif')

# %% [markdown]
# Determine number of bands in dataset

# %%
dataset.count
# Out:
# 3

# %% [markdown]
# Print size of dataset image

# %%
print (dataset.width, dataset.height)
# Out:
# 10980 10980

# %%
dataset.bounds
# Out:
# BoundingBox(left=600000.0, bottom=7890220.0, right=709800.0, top=8000020.0)

# %% [markdown]
# Read and print dataset as a Numpy array representing band 1

# %%
band1 = dataset.read(1)

# %%
band1
# Out:
# array([[226, 224, 219, ..., 108, 116, 124],
#        [220, 219, 216, ..., 116, 125, 134],
#        [209, 211, 213, ..., 137, 147, 156],
#        ...,
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254]], dtype=uint8)

# %% [markdown]
# Use Matplotlib to print the pixels from Numpy array. The image by just reading one band

# %%
array = dataset.read(1)

from matplotlib import pyplot
pyplot.imshow(array, cmap='pink')
pyplot.show()

# %%
Better image when reading three bands

# %%
array = dataset.read(3)

from matplotlib import pyplot
pyplot.imshow(array, cmap='pink')
pyplot.show()

# %%
array = dataset.read(3)

from matplotlib import pyplot
pyplot.imshow(array)
pyplot.show()
